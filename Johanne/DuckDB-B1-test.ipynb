# %% [markdown]
# ## Installere pakker

# %%
#pip install -r requirements.txt

# %% [markdown]
# ## Importering av pakker

# %%
import pyarrow as pa
import pyarrow.parquet as pq
import geopandas as gpd
from IPython.display import display
import os
import duckdb
import folium

# %% [markdown]
# # Konstante variabler

# %% [markdown]
# # Partisjonering

# %% [markdown]
# ## Partisjonering etter ship type

# %%
# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Les inn data fra en Parquet-fil
query = """
    SELECT *
    FROM read_parquet('/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet')
"""
data = con.execute(query).fetchdf()

# Lukk tilkoblingen
con.close()

# Konverter Pandas DataFrame til PyArrow Table
table = pa.Table.from_pandas(data)

# Definer output path
output_path = '/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataShipType'

# Skriv til partisjonerte Parquet-filer
pq.write_to_dataset(
    table,
    root_path=output_path,
    partition_cols=['ship_type']  # Partisjonering
)

print(f"Data er skrevet til {output_path} i partisjonerte Parquet-filer.")
# Out:
# Data er skrevet til /Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataShipType i partisjonerte Parquet-filer.

# %% [markdown]
# ## Partisjonering etter timer

# %%
# Koble til DuckDB
conn = duckdb.connect()

# Angi filbanen til geoparquet-filen
file_path = '/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet'

# Les geoparquet-filen med DuckDB
query = f"""
SELECT *, EXTRACT(HOUR FROM date_time_utc) AS hour
FROM read_parquet('{file_path}')
"""

# Kjør spørringen og hent resultatene
df = conn.execute(query).fetchdf()

# Lagre partisjonerte filer (f.eks., én fil per time)
for hour in df['hour'].unique():
    partition_df = df[df['hour'] == hour]
    partition_df.to_parquet(f'partitioned_{hour}.parquet')

# Lukk tilkoblingen
conn.close()

# %%
# Koble til DuckDB
conn = duckdb.connect()

# Angi filbanen til geoparquet-filen
file_path = '/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet'

# Angi katalogen der de partisjonerte filene skal lagres
output_dir = '/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer'

# Opprett katalogen hvis den ikke eksisterer
os.makedirs(output_dir, exist_ok=True)

# SQL-spørring for å hente dataene og partisjonere etter timer
query = f"""
SELECT *, EXTRACT(HOUR FROM date_time_utc) AS hour
FROM read_parquet('{file_path}')
"""

# Kjør spørringen og hent resultatene
df = conn.execute(query).fetchdf()

# Lagre partisjonerte filer (f.eks., én fil per time) i den angitte katalogen
for hour in df['hour'].unique():
    partition_df = df[df['hour'] == hour]

    # Bygg stien til den partisjonerte filen
    output_file = os.path.join(output_dir, f'partitioned_{hour}.parquet')

    # Lagre filen
    partition_df.to_parquet(output_file)

# Lukk tilkoblingen
conn.close()

# %% [markdown]
# # Leser filen

# %%
import pandas as pd

df = pd.read_parquet("/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/partitioned_1.parquet")
print(df.head())
# Out:
#          date_time_utc       mmsi  longitude   latitude  status  \
# 47 2024-12-01 01:54:37  257565700   7.476913  58.020353       5
# 48 2024-12-01 01:48:42  257565700   7.476913  58.020353       5
# 49 2024-12-01 01:40:51  257565700   7.476915  58.020353       5
# 50 2024-12-01 01:36:34  257565700   7.476915  58.020353       5
# 51 2024-12-01 01:34:37  257565700   7.476917  58.020353       5
#
#     course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  ...  \
# 47               195.5                0.0         -15.0       0.0    0  ...
# 48               277.8                0.0           6.0       0.0    0  ...
# 49                85.0                0.0          -9.0       0.0    0  ...
# 50                88.6                0.0         -12.0       0.0    0  ...
# 51               124.8                0.0          -7.0       0.0    0  ...
#
#           ship_name ship_type  length  draught  data_source ais_class  \
# 47  RESCUE 157 BILL        51      14      0.0            G         A
# 48  RESCUE 157 BILL        51      14      0.0            G         A
# 49  RESCUE 157 BILL        51      14      0.0            G         A
# 50  RESCUE 157 BILL        51      14      0.0            G         A
# 51  RESCUE 157 BILL        51      14      0.0            G         A
#
#                  hex_7              hex_14  \
# 47  608154275335372799  639679472713910327
# 48  608154275335372799  639679472713910327
# 49  608154275335372799  639679472713910327
# 50  608154275335372799  639679472713910327
# 51  608154275335372799  639679472713910327
#
#                                              geometry hour
# 47  b'\x01\x01\x00\x00\x00~\x81\xcd\xf7[\xe8\x1d@{...    1
# 48  b'\x01\x01\x00\x00\x00~\x81\xcd\xf7[\xe8\x1d@{...    1
# 49  b'\x01\x01\x00\x00\x00*\xe3\xdfg\\\xe8\x1d@{[\...    1
# 50  b'\x01\x01\x00\x00\x00*\xe3\xdfg\\\xe8\x1d@{[\...    1
# 51  b'\x01\x01\x00\x00\x00_xF\xd7\\\xe8\x1d@{[\x1b...    1
#
# [5 rows x 21 columns]

# %% [markdown]
# # Filtrering av rader - Setter en limit til kun 5 rader, den henter dermet kun de første 5 radene i filen og setter det i et kart

# %%
# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Leser fra parquet-filen
query = """
    SELECT *
    FROM read_parquet('/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet')
"""

# Definer batch-størrelse til 100 rader
batch_size = 5
offset = 0

# Bygg spørring for å hente 5 rader
batch_query = f"{query} LIMIT {batch_size} OFFSET {offset}"
batch = con.execute(batch_query).fetchdf()

# Sjekk om vi har fått noen data
if len(batch) == 0:
    print("Ingen data funnet.")
else:
    print("Streamer 5 rader:")
    display(batch.head())  # Viser de første radene i en tabell

    # Hvis filen inneholder geodata, for eksempel med 'latitude' og 'longitude'-kolonner,
    # kan vi lage et enkelt Folium-kart:
    if "latitude" in batch.columns and "longitude" in batch.columns:
        avg_lat = batch["latitude"].mean()
        avg_lon = batch["longitude"].mean()
        m = folium.Map(location=[avg_lat, avg_lon], zoom_start=7)

        for _, row in batch.iterrows():
            lat = row["latitude"]
            lon = row["longitude"]
            if not pd.isna(lat) and not pd.isna(lon):
                folium.Marker(
                    location=[lat, lon],
                    popup=str(row.iloc[:5].to_dict())
                ).add_to(m)

        display(m)
    else:
        print("Ingen 'latitude'/'longitude'-kolonner funnet.")

# Lukk tilkoblingen
con.close()
# Out:
# Streamer 5 rader:
#         date_time_utc       mmsi  longitude   latitude  status  \
# 0 2024-12-01 05:58:44  257565700   7.476903  58.020340       5
# 1 2024-12-01 05:30:48  257565700   7.476915  58.020353       5
# 2 2024-12-01 05:16:51  257565700   7.476912  58.020327       5
# 3 2024-12-01 05:12:51  257565700   7.476917  58.020340       5
# 4 2024-12-01 05:06:46  257565700   7.476915  58.020327       5
#
#    course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  \
# 0               215.0                0.0          -9.0       0.0    0
# 1                 3.2                0.0          16.0       0.0    0
# 2                55.2                0.1          15.0       0.0    0
# 3               134.2                0.0          16.0       0.0    0
# 4                26.6                0.0          10.0       0.0    0
#
#   callsign        ship_name  ship_type  length  draught data_source ais_class  \
# 0   LF5484  RESCUE 157 BILL         51      14      0.0           G         A
# 1   LF5484  RESCUE 157 BILL         51      14      0.0           G         A
# 2   LF5484  RESCUE 157 BILL         51      14      0.0           G         A
# 3   LF5484  RESCUE 157 BILL         51      14      0.0           G         A
# 4   LF5484  RESCUE 157 BILL         51      14      0.0           G         A
#
#                 hex_7              hex_14  \
# 0  608154275335372799  639679472713910703
# 1  608154275335372799  639679472713910327
# 2  608154275335372799  639679472713910663
# 3  608154275335372799  639679472713910671
# 4  608154275335372799  639679472713910663
#
#                                             geometry
# 0  [1, 1, 0, 0, 0, 97, 208, 182, 88, 89, 232, 29,...
# 1  [1, 1, 0, 0, 0, 42, 227, 223, 103, 92, 232, 29...
# 2  [1, 1, 0, 0, 0, 209, 31, 187, 135, 91, 232, 29...
# 3  [1, 1, 0, 0, 0, 95, 120, 70, 215, 92, 232, 29,...
# 4  [1, 1, 0, 0, 0, 42, 227, 223, 103, 92, 232, 29...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd05ef6059cfc5d0d67c287b1eec4264 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd05ef6059cfc5d0d67c287b1eec4264&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd05ef6059cfc5d0d67c287b1eec4264 = L.map(
#                 &quot;map_dd05ef6059cfc5d0d67c287b1eec4264&quot;,
#                 {
#                     center: [58.020337330000004, 7.47691233],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55ccee69e99bc2813471e7c0eae1a61e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55ccee69e99bc2813471e7c0eae1a61e.addTo(map_dd05ef6059cfc5d0d67c287b1eec4264);
#
#
#             var marker_28dc4aa7ce58ea450312955cfa922d64 = L.marker(
#                 [58.02034, 7.47690333],
#                 {
# }
#             ).addTo(map_dd05ef6059cfc5d0d67c287b1eec4264);
#
#
#         var popup_5e139712a5dcca29153cdf0aa6334516 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e4046d53e37b63898f86dbee3b52219 = $(`&lt;div id=&quot;html_1e4046d53e37b63898f86dbee3b52219&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;date_time_utc&#x27;: Timestamp(&#x27;2024-12-01 05:58:44&#x27;), &#x27;mmsi&#x27;: 257565700, &#x27;longitude&#x27;: 7.47690333, &#x27;latitude&#x27;: 58.02034, &#x27;status&#x27;: 5}&lt;/div&gt;`)[0];
#                 popup_5e139712a5dcca29153cdf0aa6334516.setContent(html_1e4046d53e37b63898f86dbee3b52219);
#
#
#
#         marker_28dc4aa7ce58ea450312955cfa922d64.bindPopup(popup_5e139712a5dcca29153cdf0aa6334516)
#         ;
#
#
#
#
#             var marker_87e478d3006d35d65ffee49c51dd765b = L.marker(
#                 [58.02035333, 7.476915],
#                 {
# }
#             ).addTo(map_dd05ef6059cfc5d0d67c287b1eec4264);
#
#
#         var popup_b4772298b3652b501dd404622d89de1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8350c769177d2782899c314d7b09107 = $(`&lt;div id=&quot;html_e8350c769177d2782899c314d7b09107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;date_time_utc&#x27;: Timestamp(&#x27;2024-12-01 05:30:48&#x27;), &#x27;mmsi&#x27;: 257565700, &#x27;longitude&#x27;: 7.476915, &#x27;latitude&#x27;: 58.02035333, &#x27;status&#x27;: 5}&lt;/div&gt;`)[0];
#                 popup_b4772298b3652b501dd404622d89de1d.setContent(html_e8350c769177d2782899c314d7b09107);
#
#
#
#         marker_87e478d3006d35d65ffee49c51dd765b.bindPopup(popup_b4772298b3652b501dd404622d89de1d)
#         ;
#
#
#
#
#             var marker_7fb96bc7c1de3156cd30a6dace5c2329 = L.marker(
#                 [58.02032666, 7.47691166],
#                 {
# }
#             ).addTo(map_dd05ef6059cfc5d0d67c287b1eec4264);
#
#
#         var popup_6c4fc5c64044321197dcfff4a2e37b83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0de32c7f8401b0b69c1eb879ead0ba42 = $(`&lt;div id=&quot;html_0de32c7f8401b0b69c1eb879ead0ba42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;date_time_utc&#x27;: Timestamp(&#x27;2024-12-01 05:16:51&#x27;), &#x27;mmsi&#x27;: 257565700, &#x27;longitude&#x27;: 7.47691166, &#x27;latitude&#x27;: 58.02032666, &#x27;status&#x27;: 5}&lt;/div&gt;`)[0];
#                 popup_6c4fc5c64044321197dcfff4a2e37b83.setContent(html_0de32c7f8401b0b69c1eb879ead0ba42);
#
#
#
#         marker_7fb96bc7c1de3156cd30a6dace5c2329.bindPopup(popup_6c4fc5c64044321197dcfff4a2e37b83)
#         ;
#
#
#
#
#             var marker_bc3fb69c684044b89a93cb0c745c7f12 = L.marker(
#                 [58.02034, 7.47691666],
#                 {
# }
#             ).addTo(map_dd05ef6059cfc5d0d67c287b1eec4264);
#
#
#         var popup_e06b50ba37b0644e2cb06fc859cd7545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc07970c659e0b3d3c33180c6fc005ec = $(`&lt;div id=&quot;html_dc07970c659e0b3d3c33180c6fc005ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;date_time_utc&#x27;: Timestamp(&#x27;2024-12-01 05:12:51&#x27;), &#x27;mmsi&#x27;: 257565700, &#x27;longitude&#x27;: 7.47691666, &#x27;latitude&#x27;: 58.02034, &#x27;status&#x27;: 5}&lt;/div&gt;`)[0];
#                 popup_e06b50ba37b0644e2cb06fc859cd7545.setContent(html_dc07970c659e0b3d3c33180c6fc005ec);
#
#
#
#         marker_bc3fb69c684044b89a93cb0c745c7f12.bindPopup(popup_e06b50ba37b0644e2cb06fc859cd7545)
#         ;
#
#
#
#
#             var marker_2453fd98efef404207898b0b77d3fca7 = L.marker(
#                 [58.02032666, 7.476915],
#                 {
# }
#             ).addTo(map_dd05ef6059cfc5d0d67c287b1eec4264);

# %% [markdown]
# # Filtrering av kolonner

# %%
# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Velg spesifikke kolonner
query = """
    SELECT date_time_utc, geometry, ship_name
    FROM read_parquet('/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet')
"""

# Utfør spørringen
filtered_data = con.execute(query).fetchdf()

# Vis de første radene
display(filtered_data.head())

# Lukk tilkoblingen
con.close()
# Out:
#         date_time_utc                                           geometry  \
# 0 2024-12-01 05:58:44  [1, 1, 0, 0, 0, 97, 208, 182, 88, 89, 232, 29,...
# 1 2024-12-01 05:30:48  [1, 1, 0, 0, 0, 42, 227, 223, 103, 92, 232, 29...
# 2 2024-12-01 05:16:51  [1, 1, 0, 0, 0, 209, 31, 187, 135, 91, 232, 29...
# 3 2024-12-01 05:12:51  [1, 1, 0, 0, 0, 95, 120, 70, 215, 92, 232, 29,...
# 4 2024-12-01 05:06:46  [1, 1, 0, 0, 0, 42, 227, 223, 103, 92, 232, 29...
#
#          ship_name
# 0  RESCUE 157 BILL
# 1  RESCUE 157 BILL
# 2  RESCUE 157 BILL
# 3  RESCUE 157 BILL
# 4  RESCUE 157 BILL

# %% [markdown]
# # Filtrering av tidsstempler (og visualisering i kart)

# %%
# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Definer tidsintervallet
start_time = "2024-12-01 05:12:51"
end_time = "2024-12-01 05:14:00"

# SQL-spørring for å filtrere data basert på tidspunkt
query = f"""
    SELECT *
    FROM read_parquet('/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet')
    WHERE CAST(date_time_utc AS TIMESTAMP)
    BETWEEN TIMESTAMP '{start_time}' AND TIMESTAMP '{end_time}'
"""

# Utfør spørringen og hent dataen
filtered_data = con.execute(query).fetchdf()

# Lukk tilkoblingen
con.close()


# Sjekk om vi fikk noen rader
if filtered_data.empty:
    print("Ingen data funnet i det spesifiserte tidsintervallet.")
else:
    print(f"Fant {len(filtered_data)} rader i tidsintervallet:")
    display(filtered_data)  # Viser hele den filtrerte tabellen

    # Sjekk om datasettet inneholder 'latitude' og 'longitude'
    if "latitude" in filtered_data.columns and "longitude" in filtered_data.columns:
        avg_lat = filtered_data["latitude"].mean()
        avg_lon = filtered_data["longitude"].mean()

        # Lag et Folium-kart med gjennomsnittlig senterpunkt
        m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)

        # Legg til punktene i kartet
        for _, row in filtered_data.iterrows():
            lat, lon = row["latitude"], row["longitude"]
            if not pd.isna(lat) and not pd.isna(lon):  # Sjekk at verdiene ikke er NaN
                ship_name = row.get("ship_name", "Ukjent skip")  # Erstatt med riktig kolonnenavn for skipets navn
                popup_text = f"Timestamp: {row['date_time_utc']}<br>Ship: {ship_name}"

                folium.Marker(
                    location=[lat, lon],
                    popup=popup_text,
                ).add_to(m)

        # Vis kartet
        display(m)
    else:
        print("Ingen 'latitude'/'longitude'-kolonner funnet i datasettet.")
# Out:
# Fant 15 rader i tidsintervallet:
#          date_time_utc       mmsi  longitude   latitude  status  \
# 0  2024-12-01 05:12:51  257565700   7.476917  58.020340       5
# 1  2024-12-01 05:13:58  258012180   8.034652  58.146895      15
# 2  2024-12-01 05:13:47  258012180   8.034647  58.146887      15
# 3  2024-12-01 05:13:38  258012180   8.034633  58.146860      15
# 4  2024-12-01 05:13:28  258012180   8.034620  58.146840      15
# 5  2024-12-01 05:13:18  258012180   8.034605  58.146835      15
# 6  2024-12-01 05:13:08  258012180   8.034602  58.146838      15
# 7  2024-12-01 05:12:58  258012180   8.034608  58.146845      15
# 8  2024-12-01 05:14:00  258258500   8.778695  58.461892       0
# 9  2024-12-01 05:13:50  258258500   8.778688  58.461893       0
# 10 2024-12-01 05:13:40  258258500   8.778680  58.461893       0
# 11 2024-12-01 05:13:31  258258500   8.778678  58.461895       0
# 12 2024-12-01 05:13:20  258258500   8.778680  58.461897       0
# 13 2024-12-01 05:13:10  258258500   8.778680  58.461895       0
# 14 2024-12-01 05:13:00  258258500   8.778685  58.461887       0
#
#     course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  \
# 0                134.2                0.0          16.0       0.0    0
# 1                360.0                0.0        -128.0       0.0    0
# 2                360.0                0.0        -128.0       0.0    0
# 3                360.0                0.0        -128.0       0.0    0
# 4                360.0                0.0        -128.0       0.0    0
# 5                360.0                0.0        -128.0       0.0    0
# 6                360.0                0.0        -128.0       0.0    0
# 7                360.0                0.0        -128.0       0.0    0
# 8                221.7                0.0           0.0       0.0    0
# 9                221.4                0.0           0.0       0.0    0
# 10               221.1                0.0           0.0       0.0    0
# 11               221.2                0.0           0.0       0.0    0
# 12               220.1                0.0           0.0       0.0    0
# 13               218.1                0.0           0.0       0.0    0
# 14               213.5                0.0           0.0       0.0    0
#
#    callsign             ship_name  ship_type  length  draught data_source  \
# 0    LF5484       RESCUE 157 BILL         51      14      0.0           G
# 1    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 2    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 3    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 4    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 5    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 6    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 7    LF7245   SAR NICOLAI JARLSBY         51       9      0.6           G
# 8   LDLN     RESCUE STORMBULL             51      17      1.0           G
# 9   LDLN     RESCUE STORMBULL             51      17      1.0           G
# 10  LDLN     RESCUE STORMBULL             51      17      1.0           G
# 11  LDLN     RESCUE STORMBULL             51      17      1.0           G
# 12  LDLN     RESCUE STORMBULL             51      17      1.0           G
# 13  LDLN     RESCUE STORMBULL             51      17      1.0           G
# 14  LDLN     RESCUE STORMBULL             51      17      1.0           G
#
#    ais_class               hex_7              hex_14  \
# 0          A  608154275335372799  639679472713910671
# 1          A  608155171775578111  639680369155664551
# 2          A  608155171775578111  639680369155664783
# 3          A  608155171775578111  639680369155664791
# 4          A  608155171775578111  639680369155662183
# 5          A  608155171775578111  639680369155662183
# 6          A  608155171775578111  639680369155662183
# 7          A  608155171775578111  639680369155662183
# 8          A  608155183335079935  639680380713776863
# 9          A  608155183335079935  639680380713776863
# 10         A  608155183335079935  639680380713776863
# 11         A  608155183335079935  639680380713776839
# 12         A  608155183335079935  639680380713776847
# 13         A  608155183335079935  639680380713776839
# 14         A  608155183335079935  639680380713776863
#
#                                              geometry
# 0   [1, 1, 0, 0, 0, 95, 120, 70, 215, 92, 232, 29,...
# 1   [1, 1, 0, 0, 0, 123, 231, 196, 220, 189, 17, 3...
# 2   [1, 1, 0, 0, 0, 52, 59, 255, 52, 189, 17, 32, ...
# 3   [1, 1, 0, 0, 0, 53, 103, 183, 117, 187, 17, 32...
# 4   [1, 1, 0, 0, 0, 54, 147, 111, 182, 185, 17, 32...
# 5   [1, 1, 0, 0, 0, 97, 142, 30, 191, 183, 17, 32,...
# 6   [1, 1, 0, 0, 0, 180, 44, 12, 79, 183, 17, 32, ...
# 7   [1, 1, 0, 0, 0, 209, 9, 219, 46, 184, 17, 32, ...
# 8   [1, 1, 0, 0, 0, 17, 30, 109, 28, 177, 142, 33,...
# 9   [1, 1, 0, 0, 0, 243, 64, 158, 60, 176, 142, 33...
# 10  [1, 1, 0, 0, 0, 59, 25, 28, 37, 175, 142, 33, ...
# 11  [1, 1, 0, 0, 0, 101, 232, 18, 237, 174, 142, 3...
# 12  [1, 1, 0, 0, 0, 59, 25, 28, 37, 175, 142, 33, ...
# 13  [1, 1, 0, 0, 0, 59, 25, 28, 37, 175, 142, 33, ...
# 14  [1, 1, 0, 0, 0, 130, 197, 225, 204, 175, 142, ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f440b51239a7df102b8258ab98f22638 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f440b51239a7df102b8258ab98f22638&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f440b51239a7df102b8258ab98f22638 = L.map(
#                 &quot;map_f440b51239a7df102b8258ab98f22638&quot;,
#                 {
#                     center: [58.285439442, 8.344671330666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cf31ac571603726d6165a3925109f33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8cf31ac571603726d6165a3925109f33.addTo(map_f440b51239a7df102b8258ab98f22638);
#
#
#             var marker_aec165b6cd534c36d0297aa28004daab = L.marker(
#                 [58.02034, 7.47691666],
#                 {
# }
#             ).addTo(map_f440b51239a7df102b8258ab98f22638);
#
#
#         var popup_d94b83a42b4f684e321ae865219eee64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4595aa6082eb27e87fe472c00be349fa = $(`&lt;div id=&quot;html_4595aa6082eb27e87fe472c00be349fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 05:12:51&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_d94b83a42b4f684e321ae865219eee64.setContent(html_4595aa6082eb27e87fe472c00be349fa);
#
#
#
#         marker_aec165b6cd534c36d0297aa28004daab.bindPopup(popup_d94b83a42b4f684e321ae865219eee64)
#         ;
#
#
#
#
#             var marker_3ccb13b9ee6cd10eb6ad23a6852a03f0 = L.marker(
#                 [58.146895, 8.03465166],
#                 {
# }
#             ).addTo(map_f440b51239a7df102b8258ab98f22638);
#
#
#         var popup_d367249c76013215c00ebd889cbdc880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4accc11c06704783f118d94f7017dada = $(`&lt;div id=&quot;html_4accc11c06704783f118d94f7017dada&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 05:13:58&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_d367249c76013215c00ebd889cbdc880.setContent(html_4accc11c06704783f118d94f7017dada);
#
#
#
#         marker_3ccb13b9ee6cd10eb6ad23a6852a03f0.bindPopup(popup_d367249c76013215c00ebd889cbdc880)
#         ;
#
#
#
#
#             var marker_9eee3f7421e388630eb1a28dbaf71a96 = L.marker(
#                 [58.14688666, 8.03464666],
#                 {
# }
#             ).addTo(map_f440b51239a7df102b8258ab98f22638);
#
#
#         var popup_0236c25113a830721f07660b1336f6af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae0e8c786f496a75bc3124293d871a7e = $(`&lt;div id=&quot;html_ae0e8c786f496a75bc3124293d871a7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 05:13:47&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_0236c25113a830721f07660b1336f6af.setContent(html_ae0e8c786f496a75bc3124293d871a7e);
#
#
#
#         marker_9eee3f7421e388630eb1a28dbaf71a96.bindPopup(popup_0236c25113a830721f07660b1336f6af)
#         ;
#
#
#
#
#             var marker_4b7b08fe90bc4aded05662c06e8a6cb9 = L.marker(
#                 [58.14686, 8.03463333],
#                 {
# }
#             ).addTo(map_f440b51239a7df102b8258ab98f22638);
#
#
#         var popup_4569f0ca538cd346b423afe768da7a27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55da09ef496b67fd4885e30e96512253 = $(`&lt;div id=&quot;html_55da09ef496b67fd4885e30e96512253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 05:13:38&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_4569f0ca538cd346b423afe768da7a27.setContent(html_55da09ef496b67fd4885e30e96512253);
#
#
#
#         marker_4b7b08fe90bc4aded05662c06e8a6cb9.bindPopup(popup_4569f0ca538cd346b423afe768da7a27)
#         ;
#
#
#
#
#             var marker_f3beb9dfe57c0c0dbfb2e03b26fb0d76 = L.marker(
#                 [58.14684, 8.03462],
#                 {
# }
#             ).addTo(map_f440b51239a7df102b8258ab98f22638);
#
#
#         var popup_91fc407fdce580c22ae1c5de0165b1d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39bfb12a55a51e30e51266b519b3c395 = $(`&lt;div id=&quot;html_39bfb12a55a51e30e51266b519b3c395&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 05:13:28&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_91fc407fdce580c22ae1c5de0165b1d5.setContent(html_39bfb12a55a51e30e51266b519b3c395);

# %% [markdown]
# Display av ytelse (hastighet og filstørrelse)

# %% [markdown]
# # Henter størrelse i Byte

# %%
os.path.getsize("/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet")
# Out:
# 522358

# %% [markdown]
# # Konverterer til MB

# %%
import os

# Filsti
filsti = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet"

# Hent filstørrelse i bytes
filstørrelse_bytes = os.path.getsize(filsti)

# Konverter til megabytes (MB)
filstørrelse_mb = filstørrelse_bytes / (1024 * 1024)

# Presenter resultatet
print(f"Filstørrelse: {filstørrelse_mb:.2f} MB")
# Out:
# Filstørrelse: 0.50 MB

# %% [markdown]
# # under 1000 000 konverterer til KB, over 1000 000 konverterer til MB

# %%
import os

def sjekk_filstørrelse(filsti):
    """
    Sjekker størrelsen på en fil og konverterer den til enten megabytes (MB)
    hvis større enn 100 000 bytes, eller kilobytes (KB) hvis mindre.
    """
    # Hent filstørrelse i bytes
    filstørrelse_bytes = os.path.getsize(filsti)

    if filstørrelse_bytes > 1000_000:
        filstørrelse_mb = filstørrelse_bytes / (1024 * 1024)
        return f"Filstørrelse: {filstørrelse_mb:.2f} MB"
    else:
        filstørrelse_kb = filstørrelse_bytes / 1024
        return f"Filstørrelse: {filstørrelse_kb:.2f} KB"

# %%
import os

def sjekk_filstørrelse(filsti):
    """
    Returnerer størrelsen på en fil i MB eller KB.
    """
    if not os.path.exists(filsti):
        return "Filen finnes ikke."

    filstørrelse_bytes = os.path.getsize(filsti)

    if filstørrelse_bytes > 100_000:
        filstørrelse_mb = filstørrelse_bytes / (1024 * 1024)
        return f"{filstørrelse_mb:.2f} MB"
    else:
        filstørrelse_kb = filstørrelse_bytes / 1024
        return f"{filstørrelse_kb:.2f} KB"

def sammenlign_filstørrelse(original_fil, filtrert_fil):
    """
    Sammenligner filstørrelsen før og etter filtrering/partisjonering.
    """
    original_størrelse = sjekk_filstørrelse(original_fil)
    filtrert_størrelse = sjekk_filstørrelse(filtrert_fil)

    print(f"Original filstørrelse: {original_størrelse}")
    print(f"Filtrert/partisjonert filstørrelse: {filtrert_størrelse}")

# Eksempel på bruk:
original_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet"
filtrert_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/partitioned_1.parquet"

sammenlign_filstørrelse(original_fil, filtrert_fil)
# Out:
# Original filstørrelse: 0.50 MB
# Filtrert/partisjonert filstørrelse: 86.09 KB

# %% [markdown]
# # Filtrering av de partisjonerte filene etter tid

# %%
# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Definer tidsintervallet
start_time = "2024-12-01 11:12:51"
end_time = "2024-12-01 11:14:00"

# SQL-spørring for å filtrere data basert på tidspunkt
query = f"""
    SELECT *
    FROM read_parquet('/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/partitioned_11.parquet')
    WHERE CAST(date_time_utc AS TIMESTAMP)
    BETWEEN TIMESTAMP '{start_time}' AND TIMESTAMP '{end_time}'
"""

# Utfør spørringen og hent dataen
filtered_data = con.execute(query).fetchdf()

# Lukk tilkoblingen
con.close()


# Sjekk om vi fikk noen rader
if filtered_data.empty:
    print("Ingen data funnet i det spesifiserte tidsintervallet.")
else:
    print(f"Fant {len(filtered_data)} rader i tidsintervallet:")
    display(filtered_data)  # Viser hele den filtrerte tabellen

    # Sjekk om datasettet inneholder 'latitude' og 'longitude'
    if "latitude" in filtered_data.columns and "longitude" in filtered_data.columns:
        avg_lat = filtered_data["latitude"].mean()
        avg_lon = filtered_data["longitude"].mean()

        # Lag et Folium-kart med gjennomsnittlig senterpunkt
        m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)

        # Legg til punktene i kartet
        for _, row in filtered_data.iterrows():
            lat, lon = row["latitude"], row["longitude"]
            if not pd.isna(lat) and not pd.isna(lon):  # Sjekk at verdiene ikke er NaN
                ship_name = row.get("ship_name", "Ukjent skip")  # Erstatt med riktig kolonnenavn for skipets navn
                popup_text = f"Timestamp: {row['date_time_utc']}<br>Ship: {ship_name}"

                folium.Marker(
                    location=[lat, lon],
                    popup=popup_text,
                ).add_to(m)

        # Vis kartet
        display(m)
    else:
        print("Ingen 'latitude'/'longitude'-kolonner funnet i datasettet.")
# Out:
# Fant 13 rader i tidsintervallet:
#          date_time_utc       mmsi  longitude   latitude  status  \
# 0  2024-12-01 11:13:58  258012180   8.034695  58.146992      15
# 1  2024-12-01 11:13:48  258012180   8.034695  58.146987      15
# 2  2024-12-01 11:13:39  258012180   8.034697  58.146982      15
# 3  2024-12-01 11:13:27  258012180   8.034702  58.146982      15
# 4  2024-12-01 11:13:19  258012180   8.034703  58.146980      15
# 5  2024-12-01 11:13:08  258012180   8.034703  58.146978      15
# 6  2024-12-01 11:12:58  258012180   8.034702  58.146975      15
# 7  2024-12-01 11:13:50  258258500   8.778725  58.461933       0
# 8  2024-12-01 11:13:41  258258500   8.778723  58.461930       0
# 9  2024-12-01 11:13:30  258258500   8.778703  58.461888       0
# 10 2024-12-01 11:13:21  258258500   8.778715  58.461887       0
# 11 2024-12-01 11:13:10  258258500   8.778728  58.461890       0
# 12 2024-12-01 11:13:01  258258500   8.778742  58.461907       0
#
#     course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  ...  \
# 0                360.0                0.0        -128.0       0.0    0  ...
# 1                360.0                0.0        -128.0       0.0    0  ...
# 2                360.0                0.0        -128.0       0.0    0  ...
# 3                360.0                0.0        -128.0       0.0    0  ...
# 4                360.0                0.0        -128.0       0.0    0  ...
# 5                360.0                0.0        -128.0       0.0    0  ...
# 6                360.0                0.0        -128.0       0.0    0  ...
# 7                231.7                0.0           0.0       0.0    0  ...
# 8                233.9                0.0           0.0       0.0    0  ...
# 9                232.4                0.1           0.0       0.0    0  ...
# 10               232.1                0.0           0.0       0.0    0  ...
# 11               234.0                0.0           0.0       0.0    0  ...
# 12               238.4                0.0           0.0       0.0    0  ...
#
#    ship_type length  draught  data_source  ais_class               hex_7  \
# 0         51      9      0.6            G          A  608155171775578111
# 1         51      9      0.6            G          A  608155171775578111
# 2         51      9      0.6            G          A  608155171775578111
# 3         51      9      0.6            G          A  608155171775578111
# 4         51      9      0.6            G          A  608155171775578111
# 5         51      9      0.6            G          A  608155171775578111
# 6         51      9      0.6            G          A  608155171775578111
# 7         51     17      1.0            G          A  608155183335079935
# 8         51     17      1.0            G          A  608155183335079935
# 9         51     17      1.0            G          A  608155183335079935
# 10        51     17      1.0            G          A  608155183335079935
# 11        51     17      1.0            G          A  608155183335079935
# 12        51     17      1.0            G          A  608155183335079935
#
#                 hex_14                                           geometry  \
# 0   639680369155664495  [1, 1, 0, 0, 0, 96, 171, 4, 139, 195, 17, 32, ...
# 1   639680369155664455  [1, 1, 0, 0, 0, 96, 171, 4, 139, 195, 17, 32, ...
# 2   639680369155664455  [1, 1, 0, 0, 0, 251, 245, 183, 194, 195, 17, 3...
# 3   639680369155664455  [1, 1, 0, 0, 0, 66, 162, 125, 106, 196, 17, 32...
# 4   639680369155664455  [1, 1, 0, 0, 0, 24, 211, 134, 162, 196, 17, 32...
# 5   639680369155664455  [1, 1, 0, 0, 0, 24, 211, 134, 162, 196, 17, 32...
# 6   639680369155664455  [1, 1, 0, 0, 0, 66, 162, 125, 106, 196, 17, 32...
# 7   639680380713654687  [1, 1, 0, 0, 0, 187, 39, 15, 11, 181, 142, 33,...
# 8   639680380713654679  [1, 1, 0, 0, 0, 229, 246, 5, 211, 180, 142, 33...
# 9   639680380713776863  [1, 1, 0, 0, 0, 201, 69, 239, 51, 178, 142, 33...
# 10  639680380713776863  [1, 1, 0, 0, 0, 45, 207, 131, 187, 179, 142, 3...
# 11  639680380713655671  [1, 1, 0, 0, 0, 44, 163, 203, 122, 181, 142, 3...
# 12  639680380713655655  [1, 1, 0, 0, 0, 43, 119, 19, 58, 183, 142, 33,...
#
#     hour __index_level_0__
# 0     11              3969
# 1     11              3970
# 2     11              3971
# 3     11              3972
# 4     11              3973
# 5     11              3974
# 6     11              3975
# 7     11             15462
# 8     11             15463
# 9     11             15464
# 10    11             15465
# 11    11             15466
# 12    11             15467
#
# [13 rows x 22 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9baf9ddf99723a34fcaa97a3b3ec32db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9baf9ddf99723a34fcaa97a3b3ec32db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9baf9ddf99723a34fcaa97a3b3ec32db = L.map(
#                 &quot;map_9baf9ddf99723a34fcaa97a3b3ec32db&quot;,
#                 {
#                     center: [58.292331534615386, 8.378094868461538],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_687f576f6e057d1a145ea259385c1604 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_687f576f6e057d1a145ea259385c1604.addTo(map_9baf9ddf99723a34fcaa97a3b3ec32db);
#
#
#             var marker_f8300477b6f7840f98b4dcc7fe431e03 = L.marker(
#                 [58.14699166, 8.034695],
#                 {
# }
#             ).addTo(map_9baf9ddf99723a34fcaa97a3b3ec32db);
#
#
#         var popup_d2b29e717dc257c5fc352e1c2f1ef7bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e445d99c80f3e10b77116a362fa0516 = $(`&lt;div id=&quot;html_1e445d99c80f3e10b77116a362fa0516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:13:58&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_d2b29e717dc257c5fc352e1c2f1ef7bb.setContent(html_1e445d99c80f3e10b77116a362fa0516);
#
#
#
#         marker_f8300477b6f7840f98b4dcc7fe431e03.bindPopup(popup_d2b29e717dc257c5fc352e1c2f1ef7bb)
#         ;
#
#
#
#
#             var marker_c2e090f79bf137bf36809ca14813803c = L.marker(
#                 [58.14698666, 8.034695],
#                 {
# }
#             ).addTo(map_9baf9ddf99723a34fcaa97a3b3ec32db);
#
#
#         var popup_72a95f5b69747ee8ab9792a123a653a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aacd0ab0e218db5441b6875c1aa62d2e = $(`&lt;div id=&quot;html_aacd0ab0e218db5441b6875c1aa62d2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:13:48&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_72a95f5b69747ee8ab9792a123a653a8.setContent(html_aacd0ab0e218db5441b6875c1aa62d2e);
#
#
#
#         marker_c2e090f79bf137bf36809ca14813803c.bindPopup(popup_72a95f5b69747ee8ab9792a123a653a8)
#         ;
#
#
#
#
#             var marker_e28a63bf5b3e24bc3974485df8c568bf = L.marker(
#                 [58.14698166, 8.03469666],
#                 {
# }
#             ).addTo(map_9baf9ddf99723a34fcaa97a3b3ec32db);
#
#
#         var popup_9a64669fcbc7208897587020a18058ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2070677f2eaec58d21f857145840fdf = $(`&lt;div id=&quot;html_d2070677f2eaec58d21f857145840fdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:13:39&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_9a64669fcbc7208897587020a18058ad.setContent(html_d2070677f2eaec58d21f857145840fdf);
#
#
#
#         marker_e28a63bf5b3e24bc3974485df8c568bf.bindPopup(popup_9a64669fcbc7208897587020a18058ad)
#         ;
#
#
#
#
#             var marker_717970dca645525ddf1536980ad1c11d = L.marker(
#                 [58.14698166, 8.03470166],
#                 {
# }
#             ).addTo(map_9baf9ddf99723a34fcaa97a3b3ec32db);
#
#
#         var popup_ca3669e361e952e8d6d90be3b1b50fb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81055a581461a918bf58a22a79040217 = $(`&lt;div id=&quot;html_81055a581461a918bf58a22a79040217&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:13:27&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_ca3669e361e952e8d6d90be3b1b50fb3.setContent(html_81055a581461a918bf58a22a79040217);
#
#
#
#         marker_717970dca645525ddf1536980ad1c11d.bindPopup(popup_ca3669e361e952e8d6d90be3b1b50fb3)
#         ;
#
#
#
#
#             var marker_1a1900d7064793dbf56819550dca7a26 = L.marker(
#                 [58.14698, 8.03470333],
#                 {
# }
#             ).addTo(map_9baf9ddf99723a34fcaa97a3b3ec32db);
#
#
#         var popup_256d453ea4547825799f9a1ae6aed33a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16dbdcff9cca7c5f5f915e9409a63c6d = $(`&lt;div id=&quot;html_16dbdcff9cca7c5f5f915e9409a63c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:13:19&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_256d453ea4547825799f9a1ae6aed33a.setContent(html_16dbdcff9cca7c5f5f915e94

# %% [markdown]
# # Nedlasting av filtrert fil

# %%
def sjekk_filstørrelse(filsti):
    """ Returnerer størrelsen på en fil i MB eller KB """
    if not os.path.exists(filsti):
        return "Fil ikke funnet"

    filstørrelse_bytes = os.path.getsize(filsti)
    if filstørrelse_bytes > 100_000:
        return f"{filstørrelse_bytes / (1024 * 1024):.2f} MB"
    else:
        return f"{filstørrelse_bytes / 1024:.2f} KB"

def sammenlign_filstørrelser(original_fil, partisjonert_fil, filtrert_fil):
    """ Sammenligner filstørrelsene før og etter filtrering/partisjonering """
    print(f"Original filstørrelse: {sjekk_filstørrelse(original_fil)}")
    print(f"Partisjonert filstørrelse: {sjekk_filstørrelse(partisjonert_fil)}")
    print(f"Filstørrelse etter filtrering: {sjekk_filstørrelse(filtrert_fil)}")

# Definer filstier
original_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet"
partisjonert_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/partitioned_11.parquet"
filtrert_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/FiltrertData/filtered2.parquet"  # NY FIL

# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Definer tidsintervallet
start_time = "2024-12-01 11:13:51"
end_time = "2024-12-01 11:14:00"

# SQL-spørring for å filtrere data basert på tidspunkt
query = f"""
    SELECT *
    FROM read_parquet('{partisjonert_fil}')
    WHERE CAST(date_time_utc AS TIMESTAMP)
    BETWEEN TIMESTAMP '{start_time}' AND TIMESTAMP '{end_time}'
"""

# Utfør spørringen og hent dataen
filtered_data = con.execute(query).fetchdf()

# Lagre det filtrerte datasettet som en ny Parquet-fil
if not filtered_data.empty:
    filtered_data.to_parquet(filtrert_fil)
    print(f"Filtrert data lagret som: {filtrert_fil}")

# Lukk tilkoblingen
con.close()

# Sammenlign filstørrelser
sammenlign_filstørrelser(original_fil, partisjonert_fil, filtrert_fil)

# Visualisering hvis datasettet har latitude/longitude
if not filtered_data.empty:
    print(f"Fant {len(filtered_data)} rader i tidsintervallet:")
    display(filtered_data)

    if "latitude" in filtered_data.columns and "longitude" in filtered_data.columns:
        avg_lat = filtered_data["latitude"].mean()
        avg_lon = filtered_data["longitude"].mean()
        m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)

        for _, row in filtered_data.iterrows():
            lat, lon = row["latitude"], row["longitude"]
            if not pd.isna(lat) and not pd.isna(lon):
                ship_name = row.get("ship_name", "Ukjent skip")
                popup_text = f"Timestamp: {row['date_time_utc']}<br>Ship: {ship_name}"

                folium.Marker(
                    location=[lat, lon],
                    popup=popup_text,
                ).add_to(m)

        display(m)
    else:
        print("Ingen 'latitude'/'longitude'-kolonner funnet i datasettet.")
else:
    print("Ingen data funnet i det spesifiserte tidsintervallet.")
# Out:
# Filtrert data lagret som: /Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/FiltrertData/filtered2.parquet
# Original filstørrelse: 0.50 MB
# Partisjonert filstørrelse: 49.40 KB
# Filstørrelse etter filtrering: 12.78 KB
# Fant 1 rader i tidsintervallet:
#         date_time_utc       mmsi  longitude   latitude  status  \
# 0 2024-12-01 11:13:58  258012180   8.034695  58.146992      15
#
#    course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  ...  \
# 0               360.0                0.0        -128.0       0.0    0  ...
#
#   ship_type length  draught  data_source  ais_class               hex_7  \
# 0        51      9      0.6            G          A  608155171775578111
#
#                hex_14                                           geometry  \
# 0  639680369155664495  [1, 1, 0, 0, 0, 96, 171, 4, 139, 195, 17, 32, ...
#
#    hour __index_level_0__
# 0    11              3969
#
# [1 rows x 22 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf881cf37250f7c379f39e05331f4b25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf881cf37250f7c379f39e05331f4b25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf881cf37250f7c379f39e05331f4b25 = L.map(
#                 &quot;map_cf881cf37250f7c379f39e05331f4b25&quot;,
#                 {
#                     center: [58.14699166, 8.034695],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_554c4f333f8c4597644261bcf099dd85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_554c4f333f8c4597644261bcf099dd85.addTo(map_cf881cf37250f7c379f39e05331f4b25);
#
#
#             var marker_3bea1f4a26c0cc687b5d9f4f18551408 = L.marker(
#                 [58.14699166, 8.034695],
#                 {
# }
#             ).addTo(map_cf881cf37250f7c379f39e05331f4b25);
#
#
#         var popup_62c3173f494f7919abb7b6fde91419bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2d354fd08c22111cb58758f4bdfe4df = $(`&lt;div id=&quot;html_e2d354fd08c22111cb58758f4bdfe4df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:13:58&lt;br&gt;Ship: SAR NICOLAI JARLSBY&lt;/div&gt;`)[0];
#                 popup_62c3173f494f7919abb7b6fde91419bd.setContent(html_e2d354fd08c22111cb58758f4bdfe4df);
#
#
#
#         marker_3bea1f4a26c0cc687b5d9f4f18551408.bindPopup(popup_62c3173f494f7919abb7b6fde91419bd)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Filtrering etter både skipsnavn og tid

# %%
def sjekk_filstørrelse(filsti):
    """ Returnerer størrelsen på en fil i MB eller KB """
    if not os.path.exists(filsti):
        return "Fil ikke funnet"

    filstørrelse_bytes = os.path.getsize(filsti)
    if filstørrelse_bytes > 100_000:
        return f"{filstørrelse_bytes / (1024 * 1024):.2f} MB"
    else:
        return f"{filstørrelse_bytes / 1024:.2f} KB"

def sammenlign_filstørrelser(original_fil, partisjonert_fil, filtrert_fil):
    """ Sammenligner filstørrelsene før og etter filtrering/partisjonering """
    print(f"Original filstørrelse: {sjekk_filstørrelse(original_fil)}")
    print(f"Partisjonert filstørrelse: {sjekk_filstørrelse(partisjonert_fil)}")
    print(f"Filstørrelse etter filtrering: {sjekk_filstørrelse(filtrert_fil)}")

# Definer filstier
original_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet"
partisjonert_katalog = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/"
filtrert_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/FiltrertData/filtered_ship.parquet"  # NY FIL

# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Definer tidsintervall og skipsnavn for filtrering
start_time = "2024-12-01 11:49:51"
end_time = "2024-12-01 11:59:00"
ship_name_filter = "RESCUE 157 BILL"  # Endre dette til ønsket skipsnavn

# SQL-spørring for å filtrere data basert på tidspunkt og skipsnavn
query = f"""
    SELECT *
    FROM read_parquet('{partisjonert_fil}')
    WHERE CAST(date_time_utc AS TIMESTAMP) BETWEEN TIMESTAMP '{start_time}' AND TIMESTAMP '{end_time}'
    AND ship_name = '{ship_name_filter}'
"""

# Utfør spørringen og hent dataen
filtered_data = con.execute(query).fetchdf()

# Lagre det filtrerte datasettet som en ny Parquet-fil
if not filtered_data.empty:
    filtered_data.to_parquet(filtrert_fil)
    print(f"Filtrert data lagret som: {filtrert_fil}")

# Lukk tilkoblingen
con.close()

# Sammenlign filstørrelser
sammenlign_filstørrelser(original_fil, partisjonert_fil, filtrert_fil)

# Visualisering hvis datasettet har latitude/longitude
if not filtered_data.empty:
    print(f"Fant {len(filtered_data)} rader i tidsintervallet for skipet {ship_name_filter}:")
    display(filtered_data)

    if "latitude" in filtered_data.columns and "longitude" in filtered_data.columns:
        avg_lat = filtered_data["latitude"].mean()
        avg_lon = filtered_data["longitude"].mean()
        m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)

        for _, row in filtered_data.iterrows():
            lat, lon = row["latitude"], row["longitude"]
            if not pd.isna(lat) and not pd.isna(lon):
                ship_name = row.get("ship_name", "Ukjent skip")
                popup_text = f"Timestamp: {row['date_time_utc']}<br>Ship: {ship_name}"

                folium.Marker(
                    location=[lat, lon],
                    popup=popup_text,
                ).add_to(m)

        display(m)
    else:
        print("Ingen 'latitude'/'longitude'-kolonner funnet i datasettet.")
else:
    print(f"Ingen data funnet for skipet {ship_name_filter} i det spesifiserte tidsintervallet.")
# Out:
# Filtrert data lagret som: /Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/FiltrertData/filtered_ship.parquet
# Original filstørrelse: 0.50 MB
# Partisjonert filstørrelse: 49.40 KB
# Filstørrelse etter filtrering: 17.42 KB
# Fant 69 rader i tidsintervallet for skipet RESCUE 157 BILL:
#          date_time_utc       mmsi  longitude   latitude  status  \
# 0  2024-12-01 11:58:58  257565700   7.444183  58.000800       0
# 1  2024-12-01 11:58:57  257565700   7.444385  58.000787       0
# 2  2024-12-01 11:58:54  257565700   7.444775  58.000740       0
# 3  2024-12-01 11:58:51  257565700   7.445557  58.000633       0
# 4  2024-12-01 11:58:45  257565700   7.446935  58.000420       0
# ..                 ...        ...        ...        ...     ...
# 64 2024-12-01 11:51:00  257565700   7.489688  58.012880       0
# 65 2024-12-01 11:50:38  257565700   7.490077  58.012980       0
# 66 2024-12-01 11:50:30  257565700   7.490108  58.012973       0
# 67 2024-12-01 11:50:20  257565700   7.490153  58.012953       0
# 68 2024-12-01 11:50:00  257565700   7.490215  58.012947       0
#
#     course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  ...  \
# 0                278.5               23.4          -7.0       0.0    0  ...
# 1                278.5               23.4         -48.0       0.0    0  ...
# 2                282.1               23.0         -40.0       0.0    0  ...
# 3                289.6               23.8          46.0       0.0    0  ...
# 4                288.1               22.8         -16.0       0.0    0  ...
# ..                 ...                ...           ...       ...  ...  ...
# 64               230.2                7.5          10.0       0.0    0  ...
# 65               315.3                0.7          27.0       0.0    0  ...
# 66               296.0                0.8         -16.0       0.0    0  ...
# 67               331.6                0.1          -7.0       0.0    0  ...
# 68               163.5                0.3         -12.0       0.0    0  ...
#
#    ship_type length  draught  data_source  ais_class               hex_7  \
# 0         51     14      0.0            G          A  608154275318595583
# 1         51     14      0.0            G          A  608154275318595583
# 2         51     14      0.0            G          A  608154275318595583
# 3         51     14      0.0            G          A  608154275318595583
# 4         51     14      0.0            G          A  608154275318595583
# ..       ...    ...      ...          ...        ...                 ...
# 64        51     14      0.0            G          A  608154275251486719
# 65        51     14      0.0            G          A  608154275251486719
# 66        51     14      0.0            G          A  608154275251486719
# 67        51     14      0.0            G          A  608154275251486719
# 68        51     14      0.0            G          A  608154275251486719
#
#                 hex_14                                           geometry  \
# 0   639679472702610471  [1, 1, 0, 0, 0, 15, 29, 175, 254, 215, 198, 29...
# 1   639679472702608687  [1, 1, 0, 0, 0, 243, 84, 135, 220, 12, 199, 29...
# 2   639679472702589839  [1, 1, 0, 0, 0, 72, 80, 252, 24, 115, 199, 29,...
# 3   639679472702602447  [1, 1, 0, 0, 0, 39, 220, 76, 1, 64, 200, 29, 6...
# 4   639679472702686223  [1, 1, 0, 0, 0, 68, 192, 33, 84, 169, 201, 29,...
# ..                 ...                                                ...
# 64  639679472637102735  [1, 1, 0, 0, 0, 216, 84, 138, 219, 112, 245, 2...
# 65  639679472637105175  [1, 1, 0, 0, 0, 128, 238, 236, 167, 214, 245, ...
# 66  639679472637105327  [1, 1, 0, 0, 0, 130, 99, 67, 245, 222, 245, 29...
# 67  639679472637105311  [1, 1, 0, 0, 0, 130, 128, 41, 193, 234, 245, 2...
# 68  639679472637086519  [1, 1, 0, 0, 0, 217, 8, 196, 235, 250, 245, 29...
#
#     hour __index_level_0__
# 0     11               103
# 1     11               104
# 2     11               105
# 3     11               106
# 4     11               107
# ..   ...               ...
# 64    11               167
# 65    11               168
# 66    11               169
# 67    11               170
# 68    11               171
#
# [69 rows x 22 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d4b2f57306c8959f3e025bb2836021a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d4b2f57306c8959f3e025bb2836021a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d4b2f57306c8959f3e025bb2836021a = L.map(
#                 &quot;map_8d4b2f57306c8959f3e025bb2836021a&quot;,
#                 {
#                     center: [58.005778257681165, 7.467024827681159],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_528478796490a3de22f0946574988183 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_528478796490a3de22f0946574988183.addTo(map_8d4b2f57306c8959f3e025bb2836021a);
#
#
#             var marker_efd6dc3cde1c4d0b05995ff63ad49590 = L.marker(
#                 [58.0008, 7.44418333],
#                 {
# }
#             ).addTo(map_8d4b2f57306c8959f3e025bb2836021a);
#
#
#         var popup_fada0269f0c97ada2a64c3473c21ae32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91f10fe04338c3d3e0b12e30089cce42 = $(`&lt;div id=&quot;html_91f10fe04338c3d3e0b12e30089cce42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:58&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_fada0269f0c97ada2a64c3473c21ae32.setContent(html_91f10fe04338c3d3e0b12e30089cce42);
#
#
#
#         marker_efd6dc3cde1c4d0b05995ff63ad49590.bindPopup(popup_fada0269f0c97ada2a64c3473c21ae32)
#         ;
#
#
#
#
#             var marker_6458daeb0fe75f3338918e0e89d15147 = L.marker(
#                 [58.00078666, 7.444385],
#                 {
# }
#             ).addTo(map_8d4b2f57306c8959f3e025bb2836021a);
#
#
#         var popup_f98917e54578d0c819d21fb452ccb0c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9011837a3fd830a76cb23e75a850ff9c = $(`&lt;div id=&quot;html_9011837a3fd830a76cb23e75a850ff9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:57&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_f98917e54578d0c819d21fb452ccb0c1.setContent(html_9011837a3fd830a76cb23e75a850ff9c);
#
#
#
#         marker_6458daeb0fe75f3338918e0e89d15147.bindPopup(popup_f98917e54578d0c819d21fb452ccb0c1)
#         ;
#
#
#
#
#             var marker_32ae4548005603fe08aadd88c5fe39e2 = L.marker(
#                 [58.00074, 7.444775],
#                 {
# }
#             ).addTo(map_8d4b2f57306c8959f3e025bb2836021a);
#
#
#         var popup_24965f1de3867bd3cf6601b0c2012337 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4838a93126fb5de2009c83a2d5b09f95 = $(`&lt;div id=&quot;html_4838a93126fb5de2009c83a2d5b09f95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:54&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_24965f1de3867bd3cf6601b0c2012337.setContent(html_4838a93126fb5de2009c83a2d5b09f95);
#
#
#
#         marker_32ae4548005603fe08aadd88c5fe39e2.bindPopup(popup_24965f1de3867bd3cf6601b0c2012337)
#         ;
#
#
#
#
#             var marker_8f725a823e44b5e3246cc483b8e17101 = L.marker(
#                 [58.00063333, 7.44555666],
#                 {
# }
#             ).addTo(map_8d4b2f57306c8959f3e025bb2836021a);
#
#
#         var popup_9e4898d5069a97e8f6aff8e68789e96c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2adacf1b75ef3d1ed5acf8363988be10 = $(`&lt;div id=&quot;html_2adacf1b75ef3d1ed5acf8363988be10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:51&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_9e4898d5069a97e8f6aff8e68789e96c.setContent(html_2adacf1b75ef3d1ed5acf8363988be10);
#
#
#
#         marker_8f725a823e44b5e3246cc483b8e17101.bindPopup(popup_9e4898d5069a97e8f6aff8e68789e96c)
#         ;
#
#
#
#
#             var marker_a72a61a82c8fbde88f6354517dde1988 = L.marker(
#                 [58.00042, 7.446935],
#                 {
# }
#             ).addTo(map_8d4b2f57306c8959f3e025bb2836021a);
#
#
#         var popup_be65d3373f789f159529dfe98796b219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13ea04c89c0062c5ac8b288b3b7d9084 = $(`&lt;div id=&quot;html_13ea04c89c0062c5ac8b288b3b7d9084&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:45&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_be65d3373f789f159529dfe98796b219.setContent(html_13ea04c89c0062c5ac8b288b3b7d9084);

# %%
import pandas as pd

df = pd.read_parquet("/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/partitioned_11.parquet")
print(df)
# Out:
#             date_time_utc       mmsi  longitude   latitude  status  \
# 70    2024-12-01 11:59:58  257565700   7.430227  58.001920       0
# 71    2024-12-01 11:59:57  257565700   7.430720  58.001893       0
# 72    2024-12-01 11:59:54  257565700   7.430968  58.001893       0
# 73    2024-12-01 11:59:53  257565700   7.431710  58.001887       0
# 74    2024-12-01 11:59:50  257565700   7.432200  58.001867       0
# ...                   ...        ...        ...        ...     ...
# 15541 2024-12-01 11:00:40  258258500   8.778638  58.461863       0
# 15542 2024-12-01 11:00:31  258258500   8.778657  58.461860       0
# 15543 2024-12-01 11:00:20  258258500   8.778672  58.461868       0
# 15544 2024-12-01 11:00:11  258258500   8.778693  58.461865       0
# 15545 2024-12-01 11:00:01  258258500   8.778698  58.461865       0
#
#        course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  \
# 70                  274.2               29.1         -46.0       0.0    0
# 71                  272.1               27.9          28.0       0.0    0
# 72                  272.1               27.8          22.0       0.0    0
# 73                  275.0               29.2         -41.0       0.0    0
# 74                  275.5               27.2         -24.0       0.0    0
# ...                   ...                ...           ...       ...  ...
# 15541               308.4                0.0           0.0       0.0    0
# 15542               311.5                0.0           0.0       0.0    0
# 15543               314.0                0.0           0.0       0.0    0
# 15544               307.4                0.0           0.0       0.0    0
# 15545               305.3                0.0           0.0       0.0    0
#
#        ...             ship_name ship_type  length  draught  data_source  \
# 70     ...       RESCUE 157 BILL        51      14      0.0            G
# 71     ...       RESCUE 157 BILL        51      14      0.0            G
# 72     ...       RESCUE 157 BILL        51      14      0.0            G
# 73     ...       RESCUE 157 BILL        51      14      0.0            G
# 74     ...       RESCUE 157 BILL        51      14      0.0            G
# ...    ...                   ...       ...     ...      ...          ...
# 15541  ...  RESCUE STORMBULL            51      17      1.0            G
# 15542  ...  RESCUE STORMBULL            51      17      1.0            G
# 15543  ...  RESCUE STORMBULL            51      17      1.0            G
# 15544  ...  RESCUE STORMBULL            51      17      1.0            G
# 15545  ...  RESCUE STORMBULL            51      17      1.0            G
#
#       ais_class               hex_7              hex_14  \
# 70            A  608154274882387967  639679472260276255
# 71            A  608154274882387967  639679472260262919
# 72            A  608154274882387967  639679472260261207
# 73            A  608154274882387967  639679472260092623
# 74            A  608154274882387967  639679472260145223
# ...         ...                 ...                 ...
# 15541         A  608155183335079935  639680380713776783
# 15542         A  608155183335079935  639680380713776783
# 15543         A  608155183335079935  639680380713776855
# 15544         A  608155183335079935  639680380713655599
# 15545         A  608155183335079935  639680380713655599
#
#                                                 geometry hour
# 70     b'\x01\x01\x00\x00\x00\xedDjV\x8d\xb8\x1d@\xaa...   11
# 71     b'\x01\x01\x00\x00\x00\xb7\xee\xe6\xa9\x0e\xb9...   11
# 72     b'\x01\x01\x00\x00\x00\xd1\xd8\x0b\xc3O\xb9\x1...   11
# 73     b'\x01\x01\x00\x00\x00\xb5l\xad/\x12\xba\x1d@\...   11
# 74     b'\x01\x01\x00\x00\x00&S\x05\xa3\x92\xba\x1d@\...   11
# ...                                                  ...  ...
# 15541  b'\x01\x01\x00\x00\x00,\x86\xe5\xae\xa9\x8e!@,...   11
# 15542  b'\x01\x01\x00\x00\x00r\x06\xf3\x15\xac\x8e!@P...   11
# 15543  b'\x01\x01\x00\x00\x00H\x0bD\r\xae\x8e!@>4^\x8...   11
# 15544  b'\x01\x01\x00\x00\x00:\xedc\xe4\xb0\x8e!@b\x1...   11
# 15545  b'\x01\x01\x00\x00\x00\x81\x99)\x8c\xb1\x8e!@b...   11
#
# [953 rows x 21 columns]

# %%
import os
import duckdb
import pandas as pd
import folium
import time  # Importer time for tidtaking av hastighet

def sjekk_filstørrelse(filsti):
    """ Returnerer størrelsen på en fil i MB eller KB """
    if not os.path.exists(filsti):
        return "Fil ikke funnet"

    filstørrelse_bytes = os.path.getsize(filsti)
    if filstørrelse_bytes > 100_000:
        return f"{filstørrelse_bytes / (1024 * 1024):.2f} MB"
    else:
        return f"{filstørrelse_bytes / 1024:.2f} KB"

def sammenlign_filstørrelser(original_fil, partisjonert_fil, filtrert_fil):
    """ Sammenligner filstørrelsene før og etter filtrering/partisjonering """
    print(f"Original filstørrelse: {sjekk_filstørrelse(original_fil)}")
    print(f"Partisjonert filstørrelse: {sjekk_filstørrelse(partisjonert_fil)}")
    print(f"Filstørrelse etter filtrering: {sjekk_filstørrelse(filtrert_fil)}")

# Definer filstier
original_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/hais_2024-12-01.snappy.parquet.geo.parquet"
partisjonert_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/PartisjonertDataTimer/partitioned_11.parquet"
filtrert_fil = "/Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/FiltrertData/filtered_ship.parquet"

# Opprett DuckDB-tilkobling
con = duckdb.connect()

# Definer tidsintervall og skipsnavn for filtrering
start_time = "2024-12-01 11:49:51"
end_time = "2024-12-01 11:59:00"
ship_name_filter = "RESCUE 157 BILL"

### Mål tid for å hente data fra originalfilen ###
start_original = time.time()
query_original = f"""
    SELECT *
    FROM read_parquet('{original_fil}')
    WHERE CAST(date_time_utc AS TIMESTAMP) BETWEEN TIMESTAMP '{start_time}' AND TIMESTAMP '{end_time}'
    AND ship_name = '{ship_name_filter}'
"""
filtered_data_original = con.execute(query_original).fetchdf()
end_original = time.time()
elapsed_original = end_original - start_original
print(f"Tid brukt på å hente data fra ORIGINALFILEN: {elapsed_original:.2f} sekunder")

###Mål tid for å hente data fra partisjonert fil ###
start_partisjonert = time.time()
query_partisjonert = f"""
    SELECT *
    FROM read_parquet('{partisjonert_fil}')
    WHERE CAST(date_time_utc AS TIMESTAMP) BETWEEN TIMESTAMP '{start_time}' AND TIMESTAMP '{end_time}'
    AND ship_name = '{ship_name_filter}'
"""
filtered_data_partisjonert = con.execute(query_partisjonert).fetchdf()
end_partisjonert = time.time()
elapsed_partisjonert = end_partisjonert - start_partisjonert
print(f"Tid brukt på å hente data fra PARTISJONERT FIL: {elapsed_partisjonert:.2f} sekunder")

# Lagre det filtrerte datasettet som en ny Parquet-fil
if not filtered_data_partisjonert.empty:
    filtered_data_partisjonert.to_parquet(filtrert_fil)
    print(f"Filtrert data lagret som: {filtrert_fil}")

# Lukk tilkoblingen
con.close()

# Sammenlign filstørrelser
sammenlign_filstørrelser(original_fil, partisjonert_fil, filtrert_fil)

# Visualisering hvis datasettet har latitude/longitude
if not filtered_data_partisjonert.empty:
    print(f"Fant {len(filtered_data_partisjonert)} rader i tidsintervallet for skipet {ship_name_filter}:")
    display(filtered_data_partisjonert)

    if "latitude" in filtered_data_partisjonert.columns and "longitude" in filtered_data_partisjonert.columns:
        avg_lat = filtered_data_partisjonert["latitude"].mean()
        avg_lon = filtered_data_partisjonert["longitude"].mean()
        m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)

        for _, row in filtered_data_partisjonert.iterrows():
            lat, lon = row["latitude"], row["longitude"]
            if not pd.isna(lat) and not pd.isna(lon):
                ship_name = row.get("ship_name", "Ukjent skip")
                popup_text = f"Timestamp: {row['date_time_utc']}<br>Ship: {ship_name}"

                folium.Marker(
                    location=[lat, lon],
                    popup=popup_text,
                ).add_to(m)

        display(m)
    else:
        print("Ingen 'latitude'/'longitude'-kolonner funnet i datasettet.")
else:
    print(f"Ingen data funnet for skipet {ship_name_filter} i det spesifiserte tidsintervallet.")
# Out:
# Tid brukt på å hente data fra ORIGINALFILEN: 0.00 sekunder
# Tid brukt på å hente data fra PARTISJONERT FIL: 0.00 sekunder
# Filtrert data lagret som: /Users/johannehaakenstad/Bachelor-Filer/Github-KartAI/Johanne/data/FiltrertData/filtered_ship.parquet
# Original filstørrelse: 0.50 MB
# Partisjonert filstørrelse: 49.40 KB
# Filstørrelse etter filtrering: 17.42 KB
# Fant 69 rader i tidsintervallet for skipet RESCUE 157 BILL:
#          date_time_utc       mmsi  longitude   latitude  status  \
# 0  2024-12-01 11:58:58  257565700   7.444183  58.000800       0
# 1  2024-12-01 11:58:57  257565700   7.444385  58.000787       0
# 2  2024-12-01 11:58:54  257565700   7.444775  58.000740       0
# 3  2024-12-01 11:58:51  257565700   7.445557  58.000633       0
# 4  2024-12-01 11:58:45  257565700   7.446935  58.000420       0
# ..                 ...        ...        ...        ...     ...
# 64 2024-12-01 11:51:00  257565700   7.489688  58.012880       0
# 65 2024-12-01 11:50:38  257565700   7.490077  58.012980       0
# 66 2024-12-01 11:50:30  257565700   7.490108  58.012973       0
# 67 2024-12-01 11:50:20  257565700   7.490153  58.012953       0
# 68 2024-12-01 11:50:00  257565700   7.490215  58.012947       0
#
#     course_over_ground  speed_over_ground  rate_of_turn  maneuvre  imo  ...  \
# 0                278.5               23.4          -7.0       0.0    0  ...
# 1                278.5               23.4         -48.0       0.0    0  ...
# 2                282.1               23.0         -40.0       0.0    0  ...
# 3                289.6               23.8          46.0       0.0    0  ...
# 4                288.1               22.8         -16.0       0.0    0  ...
# ..                 ...                ...           ...       ...  ...  ...
# 64               230.2                7.5          10.0       0.0    0  ...
# 65               315.3                0.7          27.0       0.0    0  ...
# 66               296.0                0.8         -16.0       0.0    0  ...
# 67               331.6                0.1          -7.0       0.0    0  ...
# 68               163.5                0.3         -12.0       0.0    0  ...
#
#    ship_type length  draught  data_source  ais_class               hex_7  \
# 0         51     14      0.0            G          A  608154275318595583
# 1         51     14      0.0            G          A  608154275318595583
# 2         51     14      0.0            G          A  608154275318595583
# 3         51     14      0.0            G          A  608154275318595583
# 4         51     14      0.0            G          A  608154275318595583
# ..       ...    ...      ...          ...        ...                 ...
# 64        51     14      0.0            G          A  608154275251486719
# 65        51     14      0.0            G          A  608154275251486719
# 66        51     14      0.0            G          A  608154275251486719
# 67        51     14      0.0            G          A  608154275251486719
# 68        51     14      0.0            G          A  608154275251486719
#
#                 hex_14                                           geometry  \
# 0   639679472702610471  [1, 1, 0, 0, 0, 15, 29, 175, 254, 215, 198, 29...
# 1   639679472702608687  [1, 1, 0, 0, 0, 243, 84, 135, 220, 12, 199, 29...
# 2   639679472702589839  [1, 1, 0, 0, 0, 72, 80, 252, 24, 115, 199, 29,...
# 3   639679472702602447  [1, 1, 0, 0, 0, 39, 220, 76, 1, 64, 200, 29, 6...
# 4   639679472702686223  [1, 1, 0, 0, 0, 68, 192, 33, 84, 169, 201, 29,...
# ..                 ...                                                ...
# 64  639679472637102735  [1, 1, 0, 0, 0, 216, 84, 138, 219, 112, 245, 2...
# 65  639679472637105175  [1, 1, 0, 0, 0, 128, 238, 236, 167, 214, 245, ...
# 66  639679472637105327  [1, 1, 0, 0, 0, 130, 99, 67, 245, 222, 245, 29...
# 67  639679472637105311  [1, 1, 0, 0, 0, 130, 128, 41, 193, 234, 245, 2...
# 68  639679472637086519  [1, 1, 0, 0, 0, 217, 8, 196, 235, 250, 245, 29...
#
#     hour __index_level_0__
# 0     11               103
# 1     11               104
# 2     11               105
# 3     11               106
# 4     11               107
# ..   ...               ...
# 64    11               167
# 65    11               168
# 66    11               169
# 67    11               170
# 68    11               171
#
# [69 rows x 22 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcc7769a00f9983e9ae67bb88ae2eeef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcc7769a00f9983e9ae67bb88ae2eeef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcc7769a00f9983e9ae67bb88ae2eeef = L.map(
#                 &quot;map_dcc7769a00f9983e9ae67bb88ae2eeef&quot;,
#                 {
#                     center: [58.005778257681165, 7.467024827681159],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bf7e24cd89fb3b4820076946f0bab6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0bf7e24cd89fb3b4820076946f0bab6a.addTo(map_dcc7769a00f9983e9ae67bb88ae2eeef);
#
#
#             var marker_580032b4e4923369fbadeba5d2d9a592 = L.marker(
#                 [58.0008, 7.44418333],
#                 {
# }
#             ).addTo(map_dcc7769a00f9983e9ae67bb88ae2eeef);
#
#
#         var popup_b3a86d1c8e422b1fe647e286e66c00f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11f8531cd9dbbd3fe44e8787d7a153c2 = $(`&lt;div id=&quot;html_11f8531cd9dbbd3fe44e8787d7a153c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:58&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_b3a86d1c8e422b1fe647e286e66c00f8.setContent(html_11f8531cd9dbbd3fe44e8787d7a153c2);
#
#
#
#         marker_580032b4e4923369fbadeba5d2d9a592.bindPopup(popup_b3a86d1c8e422b1fe647e286e66c00f8)
#         ;
#
#
#
#
#             var marker_1510c16a51e0f8500094dde950438fbd = L.marker(
#                 [58.00078666, 7.444385],
#                 {
# }
#             ).addTo(map_dcc7769a00f9983e9ae67bb88ae2eeef);
#
#
#         var popup_2d33b875ef65951850f3272988d0a68f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4802532b0e92feac24ff1ef05f2c596 = $(`&lt;div id=&quot;html_c4802532b0e92feac24ff1ef05f2c596&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:57&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_2d33b875ef65951850f3272988d0a68f.setContent(html_c4802532b0e92feac24ff1ef05f2c596);
#
#
#
#         marker_1510c16a51e0f8500094dde950438fbd.bindPopup(popup_2d33b875ef65951850f3272988d0a68f)
#         ;
#
#
#
#
#             var marker_343a972e754c486b8dedf876fd4b3690 = L.marker(
#                 [58.00074, 7.444775],
#                 {
# }
#             ).addTo(map_dcc7769a00f9983e9ae67bb88ae2eeef);
#
#
#         var popup_e2c185f3859573b479db2d75733bef23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_406be49ef2aefa0d3a2d2c66fa8c45a1 = $(`&lt;div id=&quot;html_406be49ef2aefa0d3a2d2c66fa8c45a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:54&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_e2c185f3859573b479db2d75733bef23.setContent(html_406be49ef2aefa0d3a2d2c66fa8c45a1);
#
#
#
#         marker_343a972e754c486b8dedf876fd4b3690.bindPopup(popup_e2c185f3859573b479db2d75733bef23)
#         ;
#
#
#
#
#             var marker_6354ab97f0e7bae7080ec7067c132dbf = L.marker(
#                 [58.00063333, 7.44555666],
#                 {
# }
#             ).addTo(map_dcc7769a00f9983e9ae67bb88ae2eeef);
#
#
#         var popup_f26270629bc6b2b626820dfd1b9412fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dab3939b09583452cbf7b5fc3f421822 = $(`&lt;div id=&quot;html_dab3939b09583452cbf7b5fc3f421822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:51&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_f26270629bc6b2b626820dfd1b9412fd.setContent(html_dab3939b09583452cbf7b5fc3f421822);
#
#
#
#         marker_6354ab97f0e7bae7080ec7067c132dbf.bindPopup(popup_f26270629bc6b2b626820dfd1b9412fd)
#         ;
#
#
#
#
#             var marker_0825d4cf7bb889b9f7d65f0cd697c13a = L.marker(
#                 [58.00042, 7.446935],
#                 {
# }
#             ).addTo(map_dcc7769a00f9983e9ae67bb88ae2eeef);
#
#
#         var popup_ccaf1a98c4084eb52787424c4aa71e91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce9011036308641c948483ea8144a6ee = $(`&lt;div id=&quot;html_ce9011036308641c948483ea8144a6ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timestamp: 2024-12-01 11:58:45&lt;br&gt;Ship: RESCUE 157 BILL&lt;/div&gt;`)[0];
#                 popup_ccaf1a98c4084eb52787424c4aa71e91.setContent(html_ce9011036308641c948483ea8144a6ee);
